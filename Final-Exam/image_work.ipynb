# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('peppers.png')
imgplot = plt.imshow(img)

# %%
rgb_peppers = img[:,:,0]
plt.imshow(lum_img)

# %%
print("The dimensions of the RGB image are ")
print(rgb_peppers.ax.plot(x))
print(rgb_peppers.ax.plot(y))

print("Minimum:" + rgb_peppers.ax.plot.min(x))
print("Maximum:" + rgb_peppers.ax.plot.max(x))
median = (rgb_peppers.ax.plot.min(x) + rgb_peppers.ax.plot.max(x)) / 2
print("Median: " + median)
# Out:
# The dimensions of the RGB image are
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-5eeae3d87525> in <module>()
#       1 print("The dimensions of the RGB image are ")
# ----> 2 print(rgb_peppers.ax.plot(x))
#       3 print(rgb_peppers.ax.plot(y))
#       4
#       5 print("Minimum:" + rgb_peppers.ax.plot.min(x))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'ax'
